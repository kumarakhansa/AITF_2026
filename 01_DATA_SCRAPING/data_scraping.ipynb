# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarakhansa/AITF_2026/blob/main/01_DATA_SCRAPING/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.	Identifikasi Kebutuhan Data**

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df1 = pd.read_csv("https://raw.githubusercontent.com/kumarakhansa/AITF_2026/refs/heads/main/01_DATA_SCRAPING/penjelasan_atribut_data.csv")
df1
# Out:
#                    Nama Fitur  \
# 0             Identitas siswa
# 1       Durasi belajar harian
# 2         Durasi tidur harian
# 3  Tingkat kehadiran di kelas
# 4   Nilai akademik sebelumnya
# 5           Nilai ujian akhir
#
#                                                                                                            Alasan Pemilihan (Mengapa Penting?)
# 0            Digunakan sebagai identitas unik setiap siswa agar setiap data dapat dibedakan dan tidak terjadi duplikasi dalam proses analisis.
# 1         Menunjukkan jumlah jam belajar siswa setiap hari. Data ini penting untuk melihat hubungan antara intensitas belajar dan hasil ujian.
# 2      Menggambarkan rata-rata jam tidur siswa per hari. Data ini digunakan untuk menganalisis pengaruh pola tidur terhadap performa akademik.
# 3  Menunjukkan persentase kehadiran siswa dalam kegiatan pembelajaran. Data ini penting untuk menilai keterlibatan siswa dalam proses belajar.
# ...

# %% [markdown]
# # **2.	Pengambilan Data Menggunakan Kaggle dan Tools Lain**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30de248d-f1d2-4cef-91a1-25c2b9633765" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30de248d-f1d2-4cef-91a1-25c2b9633765">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Membaca file CSV hasil upload
df2 = pd.read_csv("student_exam_scores.csv")

# Menampilkan 5 baris pertama data
df2.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          200 non-null    object
#  1   hours_studied       200 non-null    float64
#  2   sleep_hours         200 non-null    float64
#  3   attendance_percent  200 non-null    float64
#  4   previous_scores     200 non-null    int64
#  5   exam_score          200 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# # **3.	Integrasi Data ke dalam Database atau Repository**

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/kumarakhansa/AITF_2026/refs/heads/main/01_DATA_SCRAPING/student_exam_scores.csv"
df3 = pd.read_csv(url)

df3.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3
